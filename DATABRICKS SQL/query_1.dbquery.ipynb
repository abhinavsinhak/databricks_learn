-- %%
SELECT * from customer_enr;
SELECT * from customer_enr where domain = :para_1;
SELECT IDENTIFIER(:column_name),IDENTIFIER(:location) from customer_enr;
/*
creating snippets 
view---->query snippets
*/
SELECT IDENTIFIER(:column_name),IDENTIFIER(:location) from customer_enr
where location = 'New Darryl';
/* 
creating dynamic snippets
${1:location} → First field you can edit when the snippet is inserted.
${2:domain} → Second field you can edit.
*/
SELECT * from customer_enr
where location = 'New Joseph' AND domain = 'gmail.com';
